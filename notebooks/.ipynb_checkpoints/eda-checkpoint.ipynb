# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# #### 1. Read the Data CSV

# %%
df = pd.read_csv("../data/raw/job_postings_processed.csv")
df.head()
# Out:
#        job_id  company_id                                        title  \
# 0  3757937095    437225.0  Principal Cloud Security Architect (Remote)
# 1  3757935381  19181907.0             Insights Analyst - Auto Industry
# 2  3757935001  73013724.0                                Sales Manager
# 3  3757934347  10515052.0                              Body Technician
# 4  3757934319  18391435.0                            Controls Engineer
#
#                                          description  max_salary  med_salary  \
# 0  Job Summary\nAt iHerb, we are on a mission to ...    275834.0         NaN
# 1  Who We Are\n\nEscalent is an award-winning dat...     64000.0         NaN
# 2  Position Summary: Our Sales Manager has managi...    350000.0         NaN
# 3  Company: Gerber Collision & Glass\n\nWELCOME T...        30.0         NaN
# 4  Head-huntress.com has a Direct Hire opportunit...    150000.0         NaN
#
#    min_salary pay_period formatted_work_type           location  ...  \
# ...

# %% [markdown]
# #### 2. Get a Summary of the Data

# %%
print("DataFrame Shape:", df.shape)
# Out:
# DataFrame Shape: (11111, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11111 entries, 0 to 11110
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      11111 non-null  int64
#  1   company_id                  10919 non-null  float64
#  2   title                       11111 non-null  object
#  3   description                 11111 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  0 non-null      float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  11111 non-null  object
#  8   formatted_work_type         11111 non-null  object
#  9   location                    11111 non-null  object
#  10  applies                     6601 non-null   float64
#  11  original_listed_time        11111 non-null  float64
#  12  remote_allowed              1881 non-null   float64
# ...

# %%
df.describe()
# Out:
#              job_id    company_id    max_salary  med_salary     min_salary  \
# count  1.111100e+04  1.091900e+04  1.111100e+04         0.0   11111.000000
# mean   3.722218e+09  1.074542e+07  8.880883e+04         NaN   62650.128421
# std    9.284856e+07  2.307130e+07  8.764506e+04         NaN   58732.644143
# min    3.958427e+06  1.009000e+03  1.000000e+01         NaN       7.250000
# 25%    3.694143e+09  1.558300e+04  5.100000e+01         NaN      40.945000
# 50%    3.745576e+09  3.163220e+05  8.392800e+04         NaN   62128.000000
# 75%    3.756800e+09  6.647090e+06  1.400000e+05         NaN  100000.000000
# max    3.757937e+09  1.011741e+08  1.300000e+06         NaN  800000.000000
#
#            applies  original_listed_time  remote_allowed        views  \
# count  6601.000000          1.111100e+04          1881.0  9437.000000
# mean     21.339343          1.695809e+12             1.0    71.941189
# std      51.753293          3.161378e+09             0.0   163.390996
# ...

# %% [markdown]
# #### 3. Check for Missing Values

# %%
missing_percentage = df.isnull().sum() / len(df) * 100
print(missing_percentage)
# Out:
# job_id                          0.000000
# company_id                      1.728017
# title                           0.000000
# description                     0.000000
# max_salary                      0.000000
# med_salary                    100.000000
# min_salary                      0.000000
# pay_period                      0.000000
# formatted_work_type             0.000000
# location                        0.000000
# applies                        40.590406
# original_listed_time            0.000000
# remote_allowed                 83.070831
# views                          15.066151
# job_posting_url                 0.000000
# application_url                42.606426
# application_type                0.000000
# expiry                          0.000000
# closed_time                    96.867969
# formatted_experience_level     25.641256
# skills_desc                    99.351994
# listed_time                     0.000000
# posting_domain                 48.807488
# ...

# %% [markdown]
# #### 4. Column Distribution Visualization

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# #### 5. Correlation Analysis

# %%
numeric_df = df.select_dtypes(include=[np.number])
corr_matrix = numeric_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="crest")
plt.show()

# %% [markdown]
# #### 6. Analyzing Job Titles

# %%
word_counts = Counter(" ".join(df["title"]).split())
most_common_words = word_counts.most_common(10)
for most_common_word in most_common_words:
    print(most_common_word)
# Out:
# ('-', 1796)
# ('Manager', 1705)
# ('Senior', 1028)
# ('Engineer', 1012)
# ('Sales', 692)
# ('Specialist', 570)
# ('Analyst', 537)
# ('Associate', 535)
# ('Assistant', 513)
# ('Director', 360)

# %% [markdown]
# #### 7. Salary Analysis

# %%
df[['min_salary', 'max_salary']].plot(kind='box', vert=False, figsize=(10, 6))
plt.show()

# %% [markdown]
# #### 8. Work Location Analysis

# %%
location_counts = df['location'].value_counts().head(10)
location_counts.plot(kind='barh')
plt.title('Top 10 Job Locations')
plt.show()

# %% [markdown]
# #### 9. Analyzing Application Types and Views

# %%
application_type_counts = df['application_type'].value_counts()
application_type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Application Types Distribution')
plt.show()
